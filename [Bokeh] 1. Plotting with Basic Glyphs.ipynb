# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Creating-Figures" data-toc-modified-id="Creating-Figures-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Creating Figures</a></span><ul class="toc-item"><li><span><a href="#Scatter-Markers" data-toc-modified-id="Scatter-Markers-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Scatter Markers</a></span></li><li><span><a href="#Line-Glyphs" data-toc-modified-id="Line-Glyphs-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Line Glyphs</a></span><ul class="toc-item"><li><span><a href="#Single-Lines" data-toc-modified-id="Single-Lines-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Single Lines</a></span></li><li><span><a href="#Step-Lines" data-toc-modified-id="Step-Lines-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Step Lines</a></span></li><li><span><a href="#Multiple-Lines" data-toc-modified-id="Multiple-Lines-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>Multiple Lines</a></span></li><li><span><a href="#Missing-Points" data-toc-modified-id="Missing-Points-1.2.4"><span class="toc-item-num">1.2.4&nbsp;&nbsp;</span>Missing Points</a></span></li></ul></li><li><span><a href="#Bars-and-Rectangles" data-toc-modified-id="Bars-and-Rectangles-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Bars and Rectangles</a></span><ul class="toc-item"><li><span><a href="#Rectangles" data-toc-modified-id="Rectangles-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Rectangles</a></span></li><li><span><a href="#Bars" data-toc-modified-id="Bars-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Bars</a></span></li></ul></li><li><span><a href="#Patch-Glyphs" data-toc-modified-id="Patch-Glyphs-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Patch Glyphs</a></span><ul class="toc-item"><li><span><a href="#Single-Patches" data-toc-modified-id="Single-Patches-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Single Patches</a></span></li><li><span><a href="#Multiple-Patches" data-toc-modified-id="Multiple-Patches-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Multiple Patches</a></span></li><li><span><a href="#Missing-Points" data-toc-modified-id="Missing-Points-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>Missing Points</a></span></li></ul></li><li><span><a href="#Polygons-with-Holes" data-toc-modified-id="Polygons-with-Holes-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Polygons with Holes</a></span><ul class="toc-item"><li><span><a href="#Simple-Polygon" data-toc-modified-id="Simple-Polygon-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Simple Polygon</a></span></li><li><span><a href="#Polygon-with-Holes" data-toc-modified-id="Polygon-with-Holes-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>Polygon with Holes</a></span></li><li><span><a href="#MultiPolygon-with-Separate-Parts" data-toc-modified-id="MultiPolygon-with-Separate-Parts-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>MultiPolygon with Separate Parts</a></span></li><li><span><a href="#Multiple-MultiPolygons" data-toc-modified-id="Multiple-MultiPolygons-1.5.4"><span class="toc-item-num">1.5.4&nbsp;&nbsp;</span>Multiple MultiPolygons</a></span></li></ul></li><li><span><a href="#Ovals-and-Ellipses" data-toc-modified-id="Ovals-and-Ellipses-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Ovals and Ellipses</a></span></li><li><span><a href="#Images" data-toc-modified-id="Images-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Images</a></span></li><li><span><a href="#Segmented-and-Rays" data-toc-modified-id="Segmented-and-Rays-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Segmented and Rays</a></span></li><li><span><a href="#Wedges-and-Arcs" data-toc-modified-id="Wedges-and-Arcs-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>Wedges and Arcs</a></span></li><li><span><a href="#Specialized-Curves" data-toc-modified-id="Specialized-Curves-1.10"><span class="toc-item-num">1.10&nbsp;&nbsp;</span>Specialized Curves</a></span></li></ul></li><li><span><a href="#Combining-Multiple-Glyphs" data-toc-modified-id="Combining-Multiple-Glyphs-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Combining Multiple Glyphs</a></span></li><li><span><a href="#Setting-Ranges" data-toc-modified-id="Setting-Ranges-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Setting Ranges</a></span></li><li><span><a href="#Specifying-Axis-Types" data-toc-modified-id="Specifying-Axis-Types-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Specifying Axis Types</a></span><ul class="toc-item"><li><span><a href="#Categorical-Axes" data-toc-modified-id="Categorical-Axes-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Categorical Axes</a></span></li><li><span><a href="#Datetime-Axes" data-toc-modified-id="Datetime-Axes-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Datetime Axes</a></span></li><li><span><a href="#Log-Scale-Axes" data-toc-modified-id="Log-Scale-Axes-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Log Scale Axes</a></span></li><li><span><a href="#Twin-Axes" data-toc-modified-id="Twin-Axes-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Twin Axes</a></span></li></ul></li><li><span><a href="#Adding-Annotations" data-toc-modified-id="Adding-Annotations-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Adding Annotations</a></span></li></ul></div>

# %% [markdown]
# # Creating Figures

# %% [markdown]
# ## Scatter Markers

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show

output_notebook() 

p = figure(plot_width=400, plot_height=400)

# add a circle renderer with a size, color, and alpha
p.circle([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], size=20, color="navy", alpha=0.5)

# show the results
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="ea1127ab-7aad-49dc-86b1-d5ba170bac45"></div>

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure,show

output_notebook()

p = figure(plot_width=400, plot_height=400)

# add a square renderer with a size, color, and alpha
p.square([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], size=20, color="olive", alpha=0.5)

# show the results
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1104">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="e36b0a92-cc7d-489d-927d-c59f19913269"></div>

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show

output_notebook()

p = figure(plot_width=400, plot_height=400)

# add a square renderer with a size, color, and alpha
p.triangle([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], size=20, color="firebrick", alpha=0.5)

# show the results
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1337">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="8bbb142b-d403-4adb-953a-42bee67e8a0f"></div>

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show

output_notebook()

p = figure(plot_width=400, plot_height=400)

# add a square renderer with a size, color, and alpha
p.inverted_triangle([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], size=20, color="black", alpha=0.5)

# show the results
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1467">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="9ceac412-6912-430d-98d9-b22c3e569af7"></div>

# %% [markdown]
# ## Line Glyphs

# %% [markdown]
# ### Single Lines

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show

output_notebook()

p = figure(plot_width=400, plot_height=400)

# add a line renderer
p.line([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], line_width=2)

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1606">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="971beedc-142e-4f26-a7b9-d7fefef4a977"></div>

# %% [markdown]
# ### Step Lines

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show

output_notebook()

p = figure(plot_width=400, plot_height=400)

# add a steps renderer
p.step([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], line_width=2, mode="center")

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1754">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="6dc7109d-4f5c-4ca4-bd5b-241be79409ac"></div>

# %% [markdown]
# ### Multiple Lines

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show

output_notebook()

p = figure(plot_width=400, plot_height=400)

p.multi_line([[1, 3, 2], [3, 4, 6, 6]], [[2, 1, 4], [4, 7, 8, 5]],
             color=["firebrick", "navy"], alpha=[0.8, 0.3], line_width=4)

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1911">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="8345f06f-9ca1-4e5b-927a-3869dd9847b7"></div>

# %% [markdown]
# ### Missing Points

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show

output_notebook()

p = figure(plot_width=400, plot_height=400)

# add a line renderer with a NaN
nan = float('nan')
p.line([1, 2, 3, nan, 4, 5], [6, 7, 2, 4, 4, 5], line_width=2)

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2077">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="5802deb9-7e7d-4da7-a349-6a829337fa0a"></div>

# %% [markdown]
# ## Bars and Rectangles

# %% [markdown]
# ### Rectangles

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show

output_notebook()

p = figure(plot_width=400, plot_height=400)
p.quad(top=[2, 3, 4], bottom=[1, 2, 3], left=[1, 2, 3],
       right=[1.2, 2.5, 3.7], color="#B3DE69")

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2252">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="d5ffe383-171d-4a52-8a17-265450a318be"></div>

# %% [markdown]
# ### Bars

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show

output_notebook()

p = figure(plot_width=400, plot_height=400)
p.vbar(x=[1, 2, 3], width=0.5, bottom=0,
       top=[1.2, 2.5, 3.7], color="firebrick")

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2436">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="dfd1db43-1e9a-4600-8c22-26a5efb3dc4e"></div>

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show

output_notebook()

p = figure(plot_width=400, plot_height=400)
p.hbar(y=[1, 2, 3], height=0.5, left=0,
       right=[1.2, 2.5, 3.7], color="navy")

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2629">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="2f71027a-79e4-4c78-b11e-6fb699879110"></div>

# %% [markdown]
# ## Patch Glyphs

# %% [markdown]
# ### Single Patches

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show

output_notebook()

p = figure(plot_width=400, plot_height=400)

# add a patch renderer with an alpha an line width
p.patch([1, 2, 3, 4, 5], [6, 7, 8, 7, 3], alpha=0.5, line_width=2)

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2831">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="ceb70421-8413-4442-851d-2893f47e8b71"></div>

# %% [markdown]
# ### Multiple Patches

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show

output_notebook()

p = figure(plot_width=400, plot_height=400)

p.patches([[1, 3, 2], [3, 4, 6, 6]], [[2, 1, 4], [4, 7, 8, 5]],
          color=["firebrick", "navy"], alpha=[0.8, 0.3], line_width=2)

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3042">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="9286ea8f-95b9-4932-8d3c-473d7d5f61d1"></div>

# %% [markdown]
# ### Missing Points

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show

output_notebook()

p = figure(plot_width=400, plot_height=400)

# add a patch renderer with a NaN value
nan = float('nan')
p.patch([1, 2, 3, nan, 4, 5, 6], [6, 7, 5, nan, 7, 3, 6], alpha=0.5, line_width=2)

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3262">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="cfb996c8-c92c-40bc-935e-257bbd63bf31"></div>

# %% [markdown]
# ## Polygons with Holes

# %% [markdown]
# ### Simple Polygon

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show

output_notebook()

p = figure(plot_width=400, plot_height=400)
p.multi_polygons(xs=[[[[1, 1, 2, 2]]]],
                 ys=[[[[3, 4, 4, 3]]]])

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3491">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="ad7bb21a-bf83-4922-ac9d-ea76e5b88ac4"></div>

# %% [markdown]
# ### Polygon with Holes

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show, output_file

output_notebook()

p = figure(plot_width=400, plot_height=400)
p.multi_polygons(xs=[[[ [1, 2, 2, 1], [1.2, 1.6, 1.6], [1.8, 1.8, 1.6] ]]],
                 ys=[[[ [3, 3, 4, 4], [3.2, 3.6, 3.2], [3.4, 3.8, 3.8] ]]])

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3729">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="e61db18b-f927-443b-a447-5fd5b7bd032f"></div>

# %% [markdown]
# ### MultiPolygon with Separate Parts

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show

output_notebook()

p = figure(plot_width=400, plot_height=400)
p.multi_polygons(xs=[[[ [1, 1, 2, 2], [1.2, 1.6, 1.6], [1.8, 1.8, 1.6] ], [ [3, 4, 3] ]]],
                 ys=[[[ [4, 3, 3, 4], [3.2, 3.2, 3.6], [3.4, 3.8, 3.8] ], [ [1, 1, 3] ]]])

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3976">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="f3f4e94c-2be2-46f7-9bbc-8e3d18196560"></div>

# %% [markdown]
# ### Multiple MultiPolygons

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show

output_notebook()

p = figure(plot_width=400, plot_height=400)
p.multi_polygons(
    xs=[
        [[ [1, 1, 2, 2], [1.2, 1.6, 1.6], [1.8, 1.8, 1.6] ], [ [3, 3, 4] ]],
        [[ [1, 2, 2, 1], [1.3, 1.3, 1.7, 1.7] ]]],
    ys=[
        [[ [4, 3, 3, 4], [3.2, 3.2, 3.6], [3.4, 3.8, 3.8] ], [ [1, 3, 1] ]],
        [[ [1, 1, 2, 2], [1.3, 1.7, 1.7, 1.3] ]]],
    color=['blue', 'red'])

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4232">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="00995782-d993-4a2a-a7cd-55665517aac1"></div>

# %% [markdown]
# ## Segmented and Rays

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show

output_notebook()

p = figure(plot_width=400, plot_height=400)
p.segment(x0=[1, 2, 3], y0=[1, 2, 3], x1=[1.2, 2.4, 3.1],
          y1=[1.2, 2.5, 3.7], color="#F4A582", line_width=3)

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4497">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="a8a078ae-6ace-440f-b76a-f6a62e95b493"></div>

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show

output_notebook()

p = figure(plot_width=400, plot_height=400)
p.ray(x=[1, 2, 3], y=[1, 2, 3], length=[0, 1, 2], angle=[30, 45, 60],
      angle_units="deg", color="#FB8072", line_width=2) # length=0 means infinity

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4771">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="21d06bb9-08bc-4e0a-bf85-b18085fd7768"></div>

# %% [markdown]
# ## Wedges and Arcs

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show

output_notebook()

p = figure(plot_width=400, plot_height=400)
p.arc(x=[1, 2, 3], y=[1, 2, 3], radius=0.1, start_angle=0.4, end_angle=4.8, color="navy")

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5054">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="a469bdb5-5b33-4988-94c0-c1f69dcdc9b5"></div>

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show

output_notebook()

p = figure(plot_width=400, plot_height=400)
p.wedge(x=[1, 2, 3], y=[1, 2, 3], radius=0.2, start_angle=0.4, end_angle=4.8,
        color="firebrick", alpha=0.6, direction="clock")

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5346">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="0c7c38fc-6ae3-423f-a4ed-3c568407550a"></div>

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show

output_notebook()

p = figure(plot_width=400, plot_height=400)
p.annular_wedge(x=[1, 2, 3], y=[1, 2, 3], inner_radius=0.1, outer_radius=0.25,
                start_angle=0.4, end_angle=4.8, color="green", alpha=0.6)

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5647">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="4a2a475c-fa55-4a1a-934a-60cd41fbb3d8"></div>

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show

output_notebook()

p = figure(plot_width=400, plot_height=400)
p.annulus(x=[1, 2, 3], y=[1, 2, 3], inner_radius=0.1, outer_radius=0.25,
          color="orange", alpha=0.6)

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5957">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="c875dd3a-fcd5-4a17-954c-fa1c22d8bd89"></div>

# %% [markdown]
# # Combining Multiple Glyphs

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show

output_notebook()

x = [1, 2, 3, 4, 5]
y = [6, 7, 8, 7, 3]

p = figure(plot_width=400, plot_height=400)

# add both a line and circles on the same plot
p.line(x, y, line_width=2)
p.circle(x, y, fill_color="white", size=8)

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6276">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="0874e0b4-a64e-4b4c-af8d-9a11f321d3a8"></div>

# %% [markdown]
# # Setting Ranges

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show
from bokeh.models import Range1d

output_notebook()

# create a new plot with a range set with a tuple
p = figure(plot_width=400, plot_height=400, x_range=(0, 20))

# set a range using a Range1d
p.y_range = Range1d(0, 15)

p.circle([1, 2, 3, 4, 5], [2, 5, 8, 2, 7], size=10)

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6723">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="71bd4f22-cab5-4268-a2ad-594fcc43fad2"></div>

# %% [markdown]
# # Specifying Axis Types

# %% [markdown]
# ## Categorical Axes

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show

factors = ["a", "b", "c", "d", "e", "f", "g", "h"]
x = [50, 40, 65, 10, 25, 37, 80, 60]

output_file("categorical.html")

p = figure(y_range=factors)

p.circle(x, factors, size=15, fill_color="orange", line_color="green", line_width=3)

show(p)
# Out:
#   <div class="bk-root" id="2e0d22d8-f021-4338-b973-68ba78a91d46"></div>

# %% [markdown]
# ## Datetime Axes

# %%
import pandas as pd
from bokeh.io import output_notebook
from bokeh.plotting import figure, show
from bokeh.sampledata.stocks import AAPL

df = pd.DataFrame(AAPL)
df['date'] = pd.to_datetime(df['date'])

output_notebook()

# create a new plot with a datetime axis type
p = figure(plot_width=800, plot_height=250, x_axis_type="datetime")

p.line(df['date'], df['close'], color='navy', alpha=0.5)

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7573">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="c742b98d-5fe8-42f8-b801-df327f60337a"></div>

# %% [markdown]
# ## Log Scale Axes

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, output_file, show

x = [0.1, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0]
y = [10**xx for xx in x]

output_notebook()

# create a new plot with a log axis type
p = figure(plot_width=400, plot_height=400, y_axis_type="log")

p.line(x, y, line_width=2)
p.circle(x, y, fill_color="white", size=8)

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8204">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="102ec353-36ea-4087-897d-f81a49e81f02"></div>

# %% [markdown]
# ## Twin Axes

# %%
from numpy import pi, arange, sin, linspace

from bokeh.io import output_notebook
from bokeh.plotting import figure, show
from bokeh.models import LinearAxis, Range1d

x = arange(-2*pi, 2*pi, 0.1)
y = sin(x)
y2 = linspace(0, 100, len(y))

output_notebook()

p = figure(x_range=(-6.5, 6.5), y_range=(-1.1, 1.1))

p.circle(x, y, color="red")

p.extra_y_ranges = {"foo": Range1d(start=0, end=100)}
p.circle(x, y2, color="blue", y_range_name="foo")
p.add_layout(LinearAxis(y_range_name="foo"), 'left')

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8701">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="b59babcf-1d83-437e-b62f-67aa87f0154c"></div>
